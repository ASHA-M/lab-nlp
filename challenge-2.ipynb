# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
import numpy as np
import pandas as pd
import re 
import nltk
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer

# %%
nltk.download('stopwords') 
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\A.M\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\A.M\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\A.M\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tweets = pd.read_csv('Sentiment140.csv', encoding='ISO-8859-1', header = None)
tweets.columns = ['target','id','date','flag','user','text']
tweets_sample = tweets.sample(20000)
tweets_sample
# Out:
# C:\Users\A.M\AppData\Local\Temp\ipykernel_17312\313422323.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets = pd.read_csv('Sentiment140.csv', encoding='ISO-8859-1', header = None)
#         target          id                          date      flag  \
# 1037578      4  1956543842  Thu May 28 22:06:32 PDT 2009  NO_QUERY
# 443360       0  2067537290  Sun Jun 07 12:31:14 PDT 2009  NO_QUERY
# 781203       0  2323356039  Thu Jun 25 00:27:39 PDT 2009  NO_QUERY
# 322075       0  2004059326  Tue Jun 02 07:35:59 PDT 2009  NO_QUERY
# 519301       0  2191763724  Tue Jun 16 05:55:38 PDT 2009  NO_QUERY
# ...        ...         ...                           ...       ...
# 1495565      4  2069955684  Sun Jun 07 16:50:21 PDT 2009  NO_QUERY
# 1222334      4  1990279070  Mon Jun 01 04:25:17 PDT 2009  NO_QUERY
# 434050       0  2065099278  Sun Jun 07 07:53:30 PDT 2009  NO_QUERY
# 1296336      4  2004047713  Tue Jun 02 07:34:53 PDT 2009  NO_QUERY
# 109004       0  1824438771  Sun May 17 01:23:10 PDT 2009  NO_QUERY
#
#                    user                                               text
# 1037578   PhoenixBelize  Lots of new info (pics, menus, etc.) on the we...
# 443360         mrassman  @PammaApple Sorry I'm not replying as fast, My...
# 781203           catty_  @___Felicity oh my! I'm having one of those to...
# 322075         nessatey  i am sitting here in front of my computer fall...
# 519301       ade_shayne  I have to be in the World Trade Center at 9am ...
# ...                 ...                                                ...
# 1495565          nhaaga         http://twitpic.com/6vbj0 - the super cake
# 1222334           nommo  Yay - I am off to #WordCampUK in July... geeks...
# 434050    dontspeakliar                               @anamarihearts idk.
# 1296336       SirTravis  Going to dig a few holes then build a new stud...
# 109004   simply_brandon   I FEEL LIKE WORKING OUT BECUZ IM SO EFFIN HORNY
#
# [20000 rows x 6 columns]

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# your code here

# %%
def clean_up(c):
    
    lower = c.lower()
    no_url = re.sub('http\S+', '',lower)
    string_list = re.findall('[a-z]+',no_url)

    return ' '.join(string_list)

# %%
def tokenize(t):
    return nltk.word_tokenize(t)

# %%
def stem_and_lemmatize(l):
    
    ls_list = [] 
    
    lemmatizer = WordNetLemmatizer()
    stemmer = PorterStemmer()
    
    for word in l:
        lem = lemmatizer.lemmatize(word)
        stem = stemmer.stem(lem)
        ls_list.append(stem)
    
    return ls_list

# %%
def remove_stopwords(l):
    
    stop_words = set(stopwords.words('english'))
    
    filtered_sentence = [w for w in l if not w in stop_words]
    
    return filtered_sentence

# %%
tweets_sample['text_processed'] = tweets_sample['text'].apply(clean_up).apply(tokenize).apply(stem_and_lemmatize).apply(remove_stopwords)

tweets_sample
# Out:
#         target          id                          date      flag  \
# 1037578      4  1956543842  Thu May 28 22:06:32 PDT 2009  NO_QUERY
# 443360       0  2067537290  Sun Jun 07 12:31:14 PDT 2009  NO_QUERY
# 781203       0  2323356039  Thu Jun 25 00:27:39 PDT 2009  NO_QUERY
# 322075       0  2004059326  Tue Jun 02 07:35:59 PDT 2009  NO_QUERY
# 519301       0  2191763724  Tue Jun 16 05:55:38 PDT 2009  NO_QUERY
# ...        ...         ...                           ...       ...
# 1495565      4  2069955684  Sun Jun 07 16:50:21 PDT 2009  NO_QUERY
# 1222334      4  1990279070  Mon Jun 01 04:25:17 PDT 2009  NO_QUERY
# 434050       0  2065099278  Sun Jun 07 07:53:30 PDT 2009  NO_QUERY
# 1296336      4  2004047713  Tue Jun 02 07:34:53 PDT 2009  NO_QUERY
# 109004       0  1824438771  Sun May 17 01:23:10 PDT 2009  NO_QUERY
#
#                    user                                               text  \
# 1037578   PhoenixBelize  Lots of new info (pics, menus, etc.) on the we...
# 443360         mrassman  @PammaApple Sorry I'm not replying as fast, My...
# 781203           catty_  @___Felicity oh my! I'm having one of those to...
# 322075         nessatey  i am sitting here in front of my computer fall...
# 519301       ade_shayne  I have to be in the World Trade Center at 9am ...
# ...                 ...                                                ...
# 1495565          nhaaga         http://twitpic.com/6vbj0 - the super cake
# 1222334           nommo  Yay - I am off to #WordCampUK in July... geeks...
# 434050    dontspeakliar                               @anamarihearts idk.
# 1296336       SirTravis  Going to dig a few holes then build a new stud...
# 109004   simply_brandon   I FEEL LIKE WORKING OUT BECUZ IM SO EFFIN HORNY
#
#                                             text_processed
# 1037578  [lot, new, info, pic, menu, etc, websit, red, ...
# 443360          [pammaappl, sorri, repli, fast, tweetdeck]
# 781203   [felic, oh, one, today, quit, stomach, work, t...
# 322075   [sit, front, comput, fall, asleep, long, nite,...
# 519301   [world, trade, center, tomorrow, seminar, pm, ...
# ...                                                    ...
# 1495565                                      [super, cake]
# 1222334              [yay, wordcampuk, juli, geek, summer]
# 434050                                 [anamariheart, idk]
# 1296336          [go, dig, hole, build, new, studio, tabl]
# 109004         [feel, like, work, becuz, im, effin, horni]
#
# [20000 rows x 7 columns]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
freq_dist = nltk.FreqDist()

# %%
for each_tweet in tweets_sample['text_processed']:
    for each_word in each_tweet:
        freq_dist[each_word] += 1

#https://stackoverflow.com/questions/4634787/freqdist-with-nltk

# %%
bag_of_words = list(freq_dist.items())[:5000]
bag_of_words
# Out:
# [('lot', 196),
#  ('new', 553),
#  ('info', 20),
#  ('pic', 141),
#  ('menu', 3),
#  ('etc', 24),
#  ('websit', 42),
#  ('red', 60),
#  ('ginger', 6),
#  ('phoenix', 9),
#  ('restaur', 13),
#  ('check', 146),
#  ('pammaappl', 1),
#  ('sorri', 345),
#  ('repli', 100),
#  ('fast', 48),
#  ('tweetdeck', 17),
#  ('felic', 1),
#  ('oh', 502),
#  ('one', 740),
#  ('today', 826),
#  ('quit', 69),
#  ('stomach', 39),
#  ('work', 1129),
#  ('till', 103),
#  ('sunday', 128),
#  ('fml', 17),
#  ('much', 437),
#  ('sit', 94),
#  ('front', 28),
#  ('comput', 78),
#  ('fall', 62),
#  ('asleep', 54),
#  ('long', 200),
#  ('nite', 60),
#  ('need', 540),
#  ('sleeeeeep', 1),
#  ('world', 119),
#  ('trade', 6),
#  ('center', 16),
#  ('tomorrow', 457),
#  ('seminar', 5),
#  ('pm', 56),
#  ('tweet', 261),
#  ('day', 1347),
#  ('think', 649),
#  ('wifi', 10),
#  ('tojosan', 1),
#  ('agre', 54),
#  ('anikoheartsjon', 1),
#  ('hi', 310),
#  ('aniko', 1),
#  ('stori', 48),
#  ('write', 106),
#  ('next', 222),
#  ('part', 69),
#  ('tonight', 346),
#  ('easi', 31),
#  ('lol', 766),
#  ('last', 424),
#  ('guardian', 3),
#  ('god', 109),
#  ('war', 13),
#  ('unchart', 3),
#  ('even', 282),
#  ('titl', 5),
#  ('concept', 5),
#  ('agent', 3),
#  ('make', 544),
#  ('sad', 402),
#  ('miss', 737),
#  ('soni', 7),
#  ('play', 246),
#  ('kingdom', 6),
#  ('heart', 73),
#  ('time', 799),
#  ('showeeeeeeeeeeer', 1),
#  ('numberch', 1),
#  ('realli', 609),
#  ('want', 761),
#  ('see', 660),
#  ('wait', 426),
#  ('dvd', 36),
#  ('hire', 8),
#  ('watch', 573),
#  ('final', 260),
#  ('catch', 62),
#  ('tv', 74),
#  ('year', 204),
#  ('head', 202),
#  ('ha', 511),
#  ('kill', 78),
#  ('still', 531),
#  ('im', 641),
#  ('go', 1826),
#  ('nuerolog', 1),
#  ('hospit', 26),
#  ('happi', 342),
#  ('mother', 79),
#  ('weather', 132),
#  ('look', 566),
#  ('place', 94),
#  ('cold', 109),
#  ('raini', 25),
#  ('sydney', 10),
#  ('chefsho', 1),
#  ('quantiti', 3),
#  ('qualiti', 8),
#  ('sittin', 8),
#  ('v', 50),
#  ('amp', 621),
#  ('kelli', 17),
#  ('hous', 155),
#  ('kinda', 82),
#  ('bore', 169),
#  ('shower', 58),
#  ('outsid', 82),
#  ('phone', 169),
#  ('eat', 206),
#  ('soup', 15),
#  ('xshorti', 1),
#  ('lifex', 2),
#  ('ye', 255),
#  ('doe', 116),
#  ('like', 1049),
#  ('way', 310),
#  ('take', 324),
#  ('gon', 324),
#  ('na', 581),
#  ('fabul', 13),
#  ('oasi', 2),
#  ('market', 27),
#  ('tanflchri', 1),
#  ('browni', 13),
#  ('soon', 212),
#  ('though', 289),
#  ('thaheight', 1),
#  ('hear', 139),
#  ('let', 229),
#  ('know', 654),
#  ('thought', 157),
#  ('prayer', 26),
#  ('w', 152),
#  ('famili', 89),
#  ('home', 520),
#  ('tell', 159),
#  ('taylorxtrauma', 2),
#  ('veri', 347),
#  ('excit', 169),
#  ('news', 67),
#  ('thi', 1231),
#  ('revis', 50),
#  ('sandwhich', 1),
#  ('tbh', 3),
#  ('saturday', 103),
#  ('night', 589),
#  ('gooooood', 4),
#  ('mimisaurusrex', 1),
#  ('left', 151),
#  ('dure', 35),
#  ('weekend', 224),
#  ('dreamer', 1),
#  ('blog', 82),
#  ('bob', 16),
#  ('well', 531),
#  ('slept', 39),
#  ('away', 156),
#  ('get', 1428),
#  ('done', 221),
#  ('ahead', 25),
#  ('earli', 134),
#  ('morn', 443),
#  ('goodby', 29),
#  ('banger', 3),
#  ('sister', 52),
#  ('threadless', 1),
#  ('xoada', 1),
#  ('lil', 51),
#  ('missi', 3),
#  ('mall', 20),
#  ('hour', 244),
#  ('mental', 10),
#  ('ray', 15),
#  ('render', 2),
#  ('second', 45),
#  ('max', 11),
#  ('anim', 20),
#  ('onli', 350),
#  ('lower', 11),
#  ('set', 59),
#  ('hey', 228),
#  ('seo', 4),
#  ('peep', 21),
#  ('rid', 14),
#  ('old', 142),
#  ('link', 73),
#  ('profil', 18),
#  ('appear', 13),
#  ('search', 27),
#  ('current', 36),
#  ('bring', 71),
#  ('postshaggi', 1),
#  ('forgot', 50),
#  ('cell', 20),
#  ('wa', 1243),
#  ('downtowwn', 1),
#  ('everyth', 106),
#  ('seem', 114),
#  ('lie', 34),
#  ('guess', 172),
#  ('better', 317),
#  ('say', 344),
#  ('lt', 245),
#  ('bad', 310),
#  ('fun', 385),
#  ('bride', 8),
#  ('dri', 13),
#  ('heav', 2),
#  ('limo', 2),
#  ('messag', 46),
#  ('gustbook', 1),
#  ('www', 62),
#  ('doguedebordeaux', 1),
#  ('se', 10),
#  ('pl', 25),
#  ('sign', 64),
#  ('guestbook', 1),
#  ('damn', 147),
#  ('brutal', 3),
#  ('everyon', 191),
#  ('summer', 159),
#  ('jam', 15),
#  ('nyc', 17),
#  ('dead', 39),
#  ('ran', 30),
#  ('alaina', 2),
#  ('great', 424),
#  ('start', 236),
#  ('order', 40),
#  ('food', 114),
#  ('grad', 17),
#  ('parti', 131),
#  ('haircut', 17),
#  ('promett', 1),
#  ('thank', 759),
#  ('ff', 34),
#  ('forget', 46),
#  ('human', 24),
#  ('good', 1174),
#  ('fuck', 130),
#  ('chicago', 21),
#  ('traffic', 39),
#  ('photo', 74),
#  ('late', 117),
#  ('call', 190),
#  ('rest', 78),
#  ('product', 26),
#  ('week', 369),
#  ('f', 40),
#  ('girl', 210),
#  ('mention', 33),
#  ('coldplay', 10),
#  ('onc', 75),
#  ('got', 886),
#  ('follow', 372),
#  ('relat', 18),
#  ('annoy', 47),
#  ('colombia', 1),
#  ('anymor', 69),
#  ('suck', 202),
#  ('mr', 50),
#  ('limpet', 1),
#  ('gone', 122),
#  ('fish', 27),
#  ('heaven', 10),
#  ('peac', 31),
#  ('littl', 198),
#  ('buddi', 23),
#  ('realjok', 1),
#  ('could', 291),
#  ('break', 88),
#  ('tri', 340),
#  ('upload', 43),
#  ('x', 217),
#  ('marley', 3),
#  ('hope', 597),
#  ('terribl', 44),
#  ('movi', 222),
#  ('best', 205),
#  ('ever', 176),
#  ('car', 120),
#  ('overh', 3),
#  ('die', 74),
#  ('interview', 23),
#  ('tow', 2),
#  ('back', 701),
#  ('reschedul', 3),
#  ('blueeyedbanshe', 1),
#  ('yeah', 310),
#  ('monti', 2),
#  ('bit', 156),
#  ('love', 1029),
#  ('wld', 1),
#  ('bid', 3),
#  ('whole', 74),
#  ('paycheck', 2),
#  ('wldnt', 1),
#  ('b', 138),
#  ('enough', 83),
#  ('msn', 18),
#  ('broke', 66),
#  ('fix', 77),
#  ('end', 172),
#  ('ilmfsfmiu', 1),
#  ('definit', 54),
#  ('yo', 29),
#  ('sim', 34),
#  ('omg', 163),
#  ('lost', 135),
#  ('season', 54),
#  ('sens', 16),
#  ('ep', 17),
#  ('brought', 16),
#  ('tear', 28),
#  ('made', 174),
#  ('jawww', 1),
#  ('dropppp', 1),
#  ('understand', 34),
#  ('jennytlsmith', 1),
#  ('smile', 54),
#  ('warmli', 1),
#  ('despit', 11),
#  ('tire', 227),
#  ('heard', 64),
#  ('eye', 75),
#  ('puff', 2),
#  ('swell', 2),
#  ('bare', 14),
#  ('keep', 206),
#  ('open', 77),
#  ('least', 88),
#  ('alon', 70),
#  ('cbnqtoni', 2),
#  ('club', 33),
#  ('beyonc', 8),
#  ('singl', 26),
#  ('quot', 936),
#  ('halo', 5),
#  ('repeatedli', 2),
#  ('xbox', 15),
#  ('donniewahlberg', 8),
#  ('fantast', 29),
#  ('wish', 418),
#  ('usa', 10),
#  ('en', 6),
#  ('rout', 4),
#  ('oral', 5),
#  ('surgeon', 3),
#  ('wisdom', 10),
#  ('teeth', 25),
#  ('scare', 43),
#  ('bless', 36),
#  ('lovley', 2),
#  ('green', 42),
#  ('jelli', 7),
#  ('bean', 7),
#  ('unamus', 1),
#  ('franklero', 4),
#  ('twitter', 496),
#  ('rememb', 93),
#  ('whi', 349),
#  ('bingo', 3),
#  ('atthepictur', 1),
#  ('molli', 3),
#  ('bff', 10),
#  ('samantha', 1),
#  ('awwww', 26),
#  ('use', 226),
#  ('sleepov', 5),
#  ('ag', 2),
#  ('doll', 13),
#  ('hahaha', 75),
#  ('reemski', 1),
#  ('cousin', 43),
#  ('bail', 2),
#  ('find', 194),
#  ('anyon', 110),
#  ('short', 31),
#  ('notic', 33),
#  ('egchan', 1),
#  ('awesom', 223),
#  ('friend', 301),
#  ('might', 140),
#  ('interest', 78),
#  ('hard', 120),
#  ('shoe', 34),
#  ('facebook', 49),
#  ('school', 259),
#  ('math', 47),
#  ('class', 94),
#  ('live', 172),
#  ('without', 95),
#  ('nswandrefriend', 1),
#  ('fabric', 7),
#  ('shop', 113),
#  ('vaughnonmovi', 1),
#  ('audio', 2),
#  ('review', 17),
#  ('pretti', 161),
#  ('neat', 5),
#  ('video', 123),
#  ('asap', 13),
#  ('wife', 39),
#  ('run', 130),
#  ('railo', 1),
#  ('ec', 4),
#  ('instanc', 3),
#  ('pleas', 210),
#  ('girlfriend', 14),
#  ('belinda', 1),
#  ('bee', 12),
#  ('nooo', 17),
#  ('worth', 43),
#  ('first', 229),
#  ('near', 19),
#  ('smoo', 1),
#  ('headach', 61),
#  ('motion', 2),
#  ('sick', 188),
#  ('mom', 131),
#  ('yhaw', 1),
#  ('p', 140),
#  ('congrat', 57),
#  ('laker', 32),
#  ('boy', 108),
#  ('bamboozl', 6),
#  ('sure', 197),
#  ('smashurboxx', 1),
#  ('hahau', 1),
#  ('send', 94),
#  ('swap', 1),
#  ('fastchicken', 1),
#  ('cheeki', 3),
#  ('mayb', 165),
#  ('tastebud', 1),
#  ('practic', 31),
#  ('rotten', 3),
#  ('cork', 1),
#  ('happen', 146),
#  ('often', 19),
#  ('block', 26),
#  ('anoth', 184),
#  ('britney', 7),
#  ('tommcfli', 56),
#  ('heey', 3),
#  ('tom', 46),
#  ('true', 67),
#  ('come', 488),
#  ('brasil', 2),
#  ('octob', 3),
#  ('pigg', 1),
#  ('far', 110),
#  ('addict', 23),
#  ('japanes', 5),
#  ('grip', 2),
#  ('stronger', 4),
#  ('danc', 59),
#  ('soul', 13),
#  ('pray', 37),
#  ('hatee', 1),
#  ('todayyyyyi', 1),
#  ('gt', 108),
#  ('jackpierc', 1),
#  ('finish', 161),
#  ('mine', 88),
#  ('sfmoma', 1),
#  ('indiana', 5),
#  ('luck', 115),
#  ('walk', 97),
#  ('retrorewind', 4),
#  ('sleep', 375),
#  ('help', 188),
#  ('wth', 8),
#  ('air', 52),
#  ('paulo', 2),
#  ('neergorgan', 1),
#  ('ecomonday', 1),
#  ('ya', 128),
#  ('clock', 16),
#  ('shut', 22),
#  ('ef', 8),
#  ('cheerio', 5),
#  ('bloodi', 20),
#  ('filmnoirgirl', 1),
#  ('wan', 244),
#  ('xxx', 42),
#  ('bayarea', 1),
#  ('chill', 43),
#  ('bro', 31),
#  ('tour', 48),
#  ('nearli', 22),
#  ('build', 17),
#  ('marshal', 2),
#  ('roadcas', 1),
#  ('raver', 1),
#  ('listen', 157),
#  ('sade', 2),
#  ('chaka', 1),
#  ('khan', 4),
#  ('rage', 5),
#  ('machin', 18),
#  ('abccook', 1),
#  ('feeeel', 1),
#  ('ugh', 116),
#  ('monday', 108),
#  ('mind', 75),
#  ('robangu', 1),
#  ('suppos', 37),
#  ('prefer', 21),
#  ('rodrigo', 3),
#  ('sweet', 78),
#  ('cute', 104),
#  ('aww', 103),
#  ('c', 88),
#  ('mon', 10),
#  ('lift', 7),
#  ('game', 171),
#  ('site', 63),
#  ('api', 4),
#  ('joy', 19),
#  ('wit', 35),
#  ('yr', 30),
#  ('bf', 23),
#  ('tracymarchini', 1),
#  ('went', 197),
#  ('felt', 27),
#  ('claustrophob', 1),
#  ('onto', 13),
#  ('sidewalk', 3),
#  ('wonder', 131),
#  ('rain', 185),
#  ('poorli', 8),
#  ('nap', 45),
#  ('dinner', 99),
#  ('forward', 107),
#  ('someth', 180),
#  ('g', 75),
#  ('hot', 129),
#  ('stay', 118),
#  ('awak', 65),
#  ('yeay', 3),
#  ('laptop', 48),
#  ('internet', 78),
#  ('whack', 4),
#  ('suffer', 12),
#  ('friday', 129),
#  ('afternoo', 1),
#  ('thing', 346),
#  ('never', 211),
#  ('around', 108),
#  ('clean', 85),
#  ('offic', 65),
#  ('also', 128),
#  ('obsess', 14),
#  ('score', 11),
#  ('post', 115),
#  ('nervou', 14),
#  ('angel', 17),
#  ('fine', 65),
#  ('glad', 146),
#  ('germani', 16),
#  ('infobunni', 1),
#  ('bunni', 8),
#  ('pure', 8),
#  ('ergh', 1),
#  ('guy', 257),
#  ('termin', 14),
#  ('ice', 48),
#  ('cream', 38),
#  ('rocki', 3),
#  ('bo', 18),
#  ('outta', 11),
#  ('letter', 17),
#  ('capit', 2),
#  ('sinc', 131),
#  ('coupl', 36),
#  ('month', 100),
#  ('via', 47),
#  ('iamfirehors', 1),
#  ('profit', 6),
#  ('shantipriya', 1),
#  ('peopl', 268),
#  ('bitchin', 2),
#  ('creat', 15),
#  ('intens', 8),
#  ('magic', 25),
#  ('two', 128),
#  ('j', 40),
#  ('light', 31),
#  ('fave', 23),
#  ('greysheep', 1),
#  ('ride', 64),
#  ('unicycl', 1),
#  ('befor', 170),
#  ('thouposbrook', 1),
#  ('fresh', 16),
#  ('elsewher', 2),
#  ('mani', 116),
#  ('fake', 16),
#  ('miley', 41),
#  ('believ', 110),
#  ('ormo', 2),
#  ('atnormo', 2),
#  ('line', 51),
#  ('page', 43),
#  ('read', 176),
#  ('care', 76),
#  ('bother', 21),
#  ('liesboystel', 1),
#  ('fault', 15),
#  ('r', 111),
#  ('e', 85),
#  ('l', 62),
#  ('yet', 169),
#  ('nj', 4),
#  ('sarahrot', 1),
#  ('almost', 105),
#  ('til', 58),
#  ('nice', 274),
#  ('hr', 44),
#  ('mad', 76),
#  ('neither', 13),
#  ('susan', 14),
#  ('boyl', 9),
#  ('flawless', 3),
#  ('britain', 11),
#  ('talent', 25),
#  ('book', 94),
#  ('group', 19),
#  ('trip', 82),
#  ('port', 8),
#  ('discoveri', 2),
#  ('contact', 17),
#  ('kristi', 1),
#  ('guilick', 1),
#  ('sale', 36),
#  ('dept', 2),
#  ('ladiejanni', 1),
#  ('neglect', 9),
#  ('ankita', 2),
#  ('gaba', 2),
#  ('wast', 28),
#  ('shadez', 1),
#  ('give', 156),
#  ('u', 932),
#  ('twpp', 1),
#  ('omgitspatrick', 1),
#  ('asot', 7),
#  ('pay', 76),
#  ('third', 11),
#  ('parent', 47),
#  ('cap', 5),
#  ('scariest', 2),
#  ('moment', 42),
#  ('life', 199),
#  ('xxxsupermodel', 1),
#  ('lmao', 53),
#  ('havent', 42),
#  ('eaten', 4),
#  ('haha', 366),
#  ('spanish', 11),
#  ('italian', 9),
#  ('carlsalazar', 1),
#  ('realiz', 38),
#  ('money', 66),
#  ('glass', 22),
#  ('belindaaaa', 1),
#  ('prob', 29),
#  ('updat', 102),
#  ('mdekuijp', 1),
#  ('st', 57),
#  ('stuck', 60),
#  ('behind', 21),
#  ('big', 132),
#  ('nasti', 10),
#  ('wreck', 8),
#  ('min', 46),
#  ('bed', 274),
#  ('studio', 19),
#  ('tommorow', 11),
#  ('meet', 108),
#  ('void', 3),
#  ('real', 83),
#  ('yall', 21),
#  ('viciouseleg', 1),
#  ('dont', 223),
#  ('hate', 255),
#  ('aint', 18),
#  ('weight', 15),
#  ('someon', 146),
#  ('crash', 44),
#  ('hella', 16),
#  ('quick', 20),
#  ('correctli', 4),
#  ('caus', 88),
#  ('conceit', 2),
#  ('breakfast', 58),
#  ('man', 167),
#  ('dad', 107),
#  ('ago', 64),
#  ('saurabhshah', 1),
#  ('welcom', 88),
#  ('hayleyhorcrux', 2),
#  ('toast', 13),
#  ('crumpet', 1),
#  ('obfusc', 1),
#  ('k', 49),
#  ('incred', 11),
#  ('feel', 615),
#  ('step', 19),
#  ('closer', 11),
#  ('clinch', 2),
#  ('wc', 2),
#  ('indian', 6),
#  ('player', 24),
#  ('rock', 91),
#  ('ongo', 1),
#  ('ipl', 2),
#  ('connar', 1),
#  ('okeeff', 1),
#  ('justmarta', 1),
#  ('master', 4),
#  ('lensbabi', 1),
#  ('ericwithac', 1),
#  ('amaz', 128),
#  ('razzberrymomma', 1),
#  ('graphic', 6),
#  ('design', 40),
#  ('dreamweav', 1),
#  ('found', 107),
#  ('anyth', 102),
#  ('turn', 84),
#  ('bodi', 29),
#  ('settl', 11),
#  ('jamesmoran', 1),
#  ('doctor', 32),
#  ('seri', 16),
#  ('xx', 93),
#  ('iamcyncer', 1),
#  ('half', 72),
#  ('distanc', 2),
#  ('state', 21),
#  ('tabbylagoo', 1),
#  ('album', 56),
#  ('tho', 105),
#  ('santi', 1),
#  ('katiesisnero', 1),
#  ('nebraska', 1),
#  ('achiev', 4),
#  ('nooooooo', 6),
#  ('colbi', 1),
#  ('armstrong', 2),
#  ('marri', 16),
#  ('trap', 6),
#  ('elvishsiao', 1),
#  ('support', 41),
#  ('built', 4),
#  ('share', 37),
#  ('wake', 78),
#  ('taylorswift', 9),
#  ('omgsh', 1),
#  ('legit', 4),
#  ('mickyyoochun', 1),
#  ('join', 40),
#  ('electo', 1),
#  ('music', 118),
#  ('comm', 3),
#  ('yay', 152),
#  ('metronom', 1),
#  ('paulinaheart', 1),
#  ('becaus', 150),
#  ('youu', 10),
#  ('cant', 240),
#  ('afford', 16),
#  ('demon', 5),
#  ('free', 90),
#  ('legallyblond', 1),
#  ('would', 347),
#  ('basic', 7),
#  ('gutter', 2),
#  ('sat', 42),
#  ('hone', 1),
#  ('skill', 11),
#  ('latest', 16),
#  ('greatest', 9),
#  ('cs', 3),
#  ('ani', 219),
#  ('fellow', 15),
#  ('geek', 10),
#  ('whoop', 8),
#  ('sweetlikez', 1),
#  ('tab', 8),
#  ('pictur', 103),
#  ('nicoleremond', 1),
#  ('iv', 6),
#  ('taken', 28),
#  ('busi', 123),
#  ('orient', 3),
#  ('subject', 4),
#  ('acadia', 1),
#  ('phil', 4),
#  ('jenn', 2),
#  ('un', 13),
#  ('ill', 107),
#  ('ear', 28),
#  ('infect', 11),
#  ('metion', 1),
#  ('throw', 21),
#  ('inbetween', 1),
#  ('roderickvd', 1),
#  ('tnk', 2),
#  ('univers', 17),
#  ('tokyo', 6),
#  ('april', 12),
#  ('manag', 39),
#  ('scholarship', 2),
#  ('atxggranado', 1),
#  ('readi', 151),
#  ('freak', 37),
#  ('wed', 48),
#  ('purs', 4),
#  ('noth', 145),
#  ('high', 54),
#  ('street', 28),
#  ('net', 20),
#  ('wossi', 9),
#  ('exam', 132),
#  ('english', 45),
#  ('awsom', 7),
#  ('wink', 7),
#  ('doubt', 23),
#  ('thursday', 35),
#  ('favorit', 57),
#  ('insan', 11),
#  ('hype', 4),
#  ('hp', 9),
#  ('blood', 24),
#  ('princ', 11),
#  ('alreadi', 178),
#  ('ste', 3),
#  ('except', 36),
#  ('burgl', 1),
#  ('earlier', 40),
#  ('maryjaneduck', 1),
#  ('yea', 42),
#  ('knew', 37),
#  ('tlake', 1),
#  ('hahah', 24),
#  ('clareohh', 1),
#  ('ihi', 1),
#  ('band', 43),
#  ('cd', 37),
#  ('fishfir', 1),
#  ('forth', 5),
#  ('beauti', 114),
#  ('neighborhood', 4),
#  ('jasonbradburi', 6),
#  ('hit', 83),
#  ('citi', 47),
#  ('frienddd', 1),
#  ('rough', 14),
#  ('drinkin', 4),
#  ('copenhagen', 1),
#  ('carniv', 5),
#  ('daughter', 24),
#  ('pinkgirl', 1),
#  ('whatev', 35),
#  ('johngrrr', 1),
#  ('honestli', 11),
#  ('usual', 32),
#  ('amoeba', 1),
#  ('deal', 27),
#  ('scenario', 3),
#  ('document', 4),
#  ('creativ', 12),
#  ('drowsi', 3),
#  ('juno', 3),
#  ('butttttt', 1),
#  ('andddddd', 1),
#  ('onlin', 55),
#  ('taylam', 1),
#  ('fair', 38),
#  ('enuf', 1),
#  ('hun', 25),
#  ('mystiquejewel', 1),
#  ('migrain', 16),
#  ('felicia', 3),
#  ('nicol', 11),
#  ('blast', 13),
#  ('cruis', 11),
#  ('damnit', 9),
#  ('name', 99),
#  ('bball', 1),
#  ('gona', 6),
#  ('nba', 5),
#  ('wantd', 1),
#  ('add', 62),
#  ('fb', 57),
#  ('ok', 189),
#  ('session', 16),
#  ('n', 181),
#  ('librari', 13),
#  ('chem', 4),
#  ('lab', 8),
#  ('freakin', 14),
#  ('pirat', 7),
#  ('voic', 27),
#  ('aaarrrggghhh', 1),
#  ('thomasjo', 1),
#  ('actual', 125),
#  ('tortois', 1),
#  ('approach', 7),
#  ('leav', 172),
#  ('clone', 1),
#  ('munozjos', 1),
#  ('nivk', 1),
#  ('brother', 75),
#  ('julian', 1),
#  ('shakran', 1),
#  ('megsli', 1),
#  ('board', 15),
#  ('presid', 6),
#  ('cri', 97),
#  ('ahh', 43),
#  ('sunris', 4),
#  ('hint', 3),
#  ('impstar', 1),
#  ('homework', 53),
#  ('load', 36),
#  ('nd', 45),
#  ('packin', 2),
#  ('andymihail', 1),
#  ('foart', 1),
#  ('posibil', 1),
#  ('concentrateee', 1),
#  ('federicafgn', 1),
#  ('hello', 81),
#  ('jefferaldo', 1),
#  ('svufan', 1),
#  ('jlovesd', 1),
#  ('layie', 1),
#  ('navig', 2),
#  ('control', 20),
#  ('stuff', 100),
#  ('secondli', 2),
#  ('beckybuckwild', 2),
#  ('omgggg', 3),
#  ('angelahvedi', 1),
#  ('kick', 41),
#  ('ur', 168),
#  ('said', 124),
#  ('whore', 3),
#  ('mood', 26),
#  ('unfaith', 1),
#  ('boston', 10),
#  ('promot', 14),
#  ('truevisiondubbz', 1),
#  ('problem', 66),
#  ('sweeti', 21),
#  ('relationship', 11),
#  ('sometim', 66),
#  ('randomli', 7),
#  ('unprovok', 1),
#  ('verbal', 1),
#  ('attack', 13),
#  ('toward', 8),
#  ('pokemon', 1),
#  ('macaroni', 3),
#  ('chees', 11),
#  ('h', 44),
#  ('chines', 12),
#  ('supermarket', 1),
#  ('pocki', 2),
#  ('ana', 5),
#  ('birthday', 135),
#  ('birthweek', 1),
#  ('lancearmstrong', 3),
#  ('son', 30),
#  ('lanc', 1),
#  ('jwehm', 1),
#  ('afraid', 15),
#  ('put', 102),
#  ('word', 89),
#  ('stephenfri', 8),
#  ('perezhilton', 5),
#  ('fletcher', 5),
#  ('alfa', 1),
#  ('showcas', 1),
#  ('waz', 4),
#  ('flt', 2),
#  ...]

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
